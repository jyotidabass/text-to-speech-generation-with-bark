# %% [markdown]
# <a href="https://colab.research.google.com/github/jyotidabass/text-to-speech-generation-with-bark/blob/main/text_to_speech_generation_with_bark.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Install the libraries**

# %%
# !pip install --upgrade aiobotocore botocore
# !pip install git+https://github.com/suno-ai/bark.git
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.4/73.4 kB 2.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.2/11.2 MB 78.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.1/11.1 MB 74.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.1/143.1 kB 14.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.0.4
#     Uninstalling urllib3-2.0.4:
#       Successfully uninstalled urllib3-2.0.4
# ...
#   Cloning https://github.com/suno-ai/bark.git to /tmp/pip-req-build-r7ajlmmw
#   Running command git clone --filter=blob:none --quiet https://github.com/suno-ai/bark.git /tmp/pip-req-build-r7ajlmmw
#   Resolved https://github.com/suno-ai/bark.git to commit 61710e5265cbc2f5eb098e08c6bee5d23dfff3fd
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# ...

# %% [markdown]
# # **Load the models and check the results**

# %%
from bark import SAMPLE_RATE, generate_audio, preload_models
from scipy.io.wavfile import write as write_wav
from IPython.display import Audio

# download and load all models
preload_models()

# generate audio from text
text_prompt = """
     [WOMAN] Hello, my name is Jyoti Dabass. And, I am playing with music. [music]
     [upbeat music] This is the notebook from BHARAT.
"""
audio_array = generate_audio(text_prompt)

# save audio to disk
write_wav("bark_generation.wav", SAMPLE_RATE, audio_array)

# play text in notebook
Audio(audio_array, rate=SAMPLE_RATE)
# Out:
# WARNING:bark.generation:No GPU being used. Careful, inference might be very slow!
# ...
# Downloading: "https://dl.fbaipublicfiles.com/encodec/v0/encodec_24khz-d7cc33bc.th" to /root/.cache/torch/hub/checkpoints/encodec_24khz-d7cc33bc.th
# 100%|██████████| 88.9M/88.9M [00:01<00:00, 73.3MB/s]
# ...
# 100%|██████████| 33/33 [14:13<00:00, 25.86s/it]
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# # Other samples that can be tried are as follows
# [laughter]
# [laughs]
# [sighs]
# [music]
# [gasps]
# [clears throat]
# [upbeat music]
# — or ... for hesitations
# ♪ for song lyrics
# CAPITALIZATION for emphasis of a word
# [MAN] and [WOMAN] to bias Bark toward male and female speakers, respectively
# [NARRATOR]

# %% [markdown]
# # **Please upvote if you liked the work. Thanks!!**
